# %% [markdown]
# # TASK 1 – Environment Setup & Data Ingestion

# %% [markdown]
# ### Step 1 — Install & Configure PySpark in Colab

# %%
# !pip install pyspark==3.5.1
# !pip install pymongo
# Out:
# Requirement already satisfied: pyspark==3.5.1 in /usr/local/lib/python3.12/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark==3.5.1) (0.10.9.7)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.12/dist-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from pymongo) (2.8.0)

# %% [markdown]
# ### Step 2 - Environment setup and check secrets are success

# %%
# MongoDB config
from google.colab import userdata
import os
from pymongo import MongoClient

# Get Secrets
try:
    mongo_uri = userdata.get('MONGO_URI')

    print(f"Attempting to connect with User: {mongo_uri.split(':')[1].split('@')[0]}...")
except Exception as e:
    print("Error reading secrets! Make sure 'Notebook access' is ON in the sidebar.")
    raise e

# Connect & Test
os.environ["MONGO_URI"] = mongo_uri

# Verify connection
try:
    # prove it work
    client = MongoClient(os.environ["MONGO_URI"])
    client.admin.command('ping')

    print("Authentication Successful! Connected to MongoDB Atlas.")
    print("Ready for Spark integration.")
except Exception as e:
    print(f"Connection failed: {e}")
# Out:
# Attempting to connect with User: //admin...
# Authentication Successful! Connected to MongoDB Atlas.
# Ready for Spark integration.

# %% [markdown]
# ### Step 3 – Create SparkSession with MongoDB

# %%
from pyspark.sql import SparkSession
from google.colab import userdata

mongo_uri = userdata.get("MONGO_URI")

spark = SparkSession.builder \
    .appName("MongoDB_Final_Fix") \
    .master("local[*]") \
    .config(
        "spark.jars.packages",
        "org.mongodb.spark:mongo-spark-connector_2.12:10.3.0"
    ) \
    .config("spark.mongodb.connection.uri", mongo_uri) \
    .config("spark.sql.legacy.timeParserPolicy", "LEGACY") \
    .getOrCreate()

print("Spark created successfully ✅")
# Out:
# Spark created successfully ✅

# %% [markdown]
# Check Spart connection with MongoDB JAR

# %%
print(spark.sparkContext._conf.get("spark.jars.packages"))
# Out:
# org.mongodb.spark:mongo-spark-connector_2.12:10.3.0

# %% [markdown]
# ### Step 4 - Mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BASE_PATH = "/content/drive/MyDrive/BigData_Assigenment02"
DATASET_PATH = BASE_PATH + "/Dataset/E_Commerce_Data_UK.csv"
BRONZE_PATH = BASE_PATH + "/bronze/"

# %% [markdown]
# ### Step 5 - Load dataset into spark

# %%
raw_df = spark.read.csv(
    DATASET_PATH,
    header=True,
    inferSchema=True
)

# %% [markdown]
# ### Step 6 - Display Schema

# %%
raw_df.printSchema()
# Out:
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- InvoiceDate: string (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- Country: string (nullable = true)

# %% [markdown]
# ### Step 7 - Display record count

# %%
total_records = raw_df.count()
print("Total Records in Dataset:", total_records)
# Out:
# Total Records in Dataset: 541909

# %% [markdown]
# ### Step 8 - Store Bronze Data as Partitioned Parquet

# %% [markdown]
# Convert InvoiceDate to Timestamp

# %%
from pyspark.sql.functions import to_timestamp

bronze_df = raw_df.withColumn(
    "InvoiceDate",
    to_timestamp("InvoiceDate", "M/d/yyyy HH:mm")
)

# %% [markdown]
# Add Year & Month Columns for Partitioning

# %%
from pyspark.sql.functions import year, month

bronze_df = bronze_df \
    .withColumn("year", year("InvoiceDate")) \
    .withColumn("month", month("InvoiceDate"))

# %% [markdown]
# Store Bronze Data as Partitioned Parquet

# %%
bronze_df.write \
    .mode("overwrite") \
    .partitionBy("year", "month") \
    .parquet(BRONZE_PATH)

print("Bronze Layer Saved Successfully ✅")
# Out:
# Bronze Layer Saved Successfully ✅

# %% [markdown]
# # TASK 2 – Data Cleaning & Quality Management

# %% [markdown]
# ### Step 1 - Count total records

# %%
total_records = bronze_df.count()
print("Total Records Processed:", total_records)
# Out:
# Total Records Processed: 541909

# %% [markdown]
# ### Step 2 - Missing customerID handling

# %%
from pyspark.sql.functions import col

missing_customer_count = bronze_df.filter(
    col("CustomerID").isNull()
).count()

df_step1 = bronze_df.filter(
    col("CustomerID").isNotNull()
)

print("Missing CustomerID Records Removed:", missing_customer_count)
# Out:
# Missing CustomerID Records Removed: 135080

# %% [markdown]
# ### step 3 - Negative quantities its same as product return

# %%
negative_qty_count = df_step1.filter(
    col("Quantity") < 0
).count()

df_step2 = df_step1.filter(
    col("Quantity") > 0
)

print("Negative Quantity Records Removed:", negative_qty_count)
# Out:
# Negative Quantity Records Removed: 8905

# %% [markdown]
# ### Step 4 - Cancelled invoices

# %%
cancelled_count = df_step2.filter(
    col("InvoiceNo").startswith("C")
).count()

df_step3 = df_step2.filter(
    ~col("InvoiceNo").startswith("C")
)

print("Cancelled Invoice Records Removed:", cancelled_count)
# Out:
# Cancelled Invoice Records Removed: 0

# %% [markdown]
# ### Step 5 — Invalid or Extreme Prices

# %%
invalid_price_count = df_step3.filter(
    col("UnitPrice") <= 0
).count()

df_step4 = df_step3.filter(
    col("UnitPrice") > 0
)

print("Invalid Price Records Removed:", invalid_price_count)
# Out:
# Invalid Price Records Removed: 40

# %% [markdown]
# Remove Extreme Outliers (IQR Method)

# %%
quantiles = df_step4.approxQuantile(
    "UnitPrice",
    [0.25, 0.75],
    0
)

Q1 = quantiles[0]
Q3 = quantiles[1]
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outlier_count = df_step4.filter(
    (col("UnitPrice") < lower_bound) |
    (col("UnitPrice") > upper_bound)
).count()

df_step5 = df_step4.filter(
    (col("UnitPrice") >= lower_bound) &
    (col("UnitPrice") <= upper_bound)
)

print("Extreme Price Outliers Removed:", outlier_count)
# Out:
# Extreme Price Outliers Removed: 34356

# %% [markdown]
# ### Step 6 — Remove Duplicate Records

# %%
before_dup = df_step5.count()

silver_df = df_step5.dropDuplicates()

after_dup = silver_df.count()

duplicate_removed = before_dup - after_dup

print("Duplicate Records Removed:", duplicate_removed)
# Out:
# Duplicate Records Removed: 4948

# %% [markdown]
# Final Clean Record Count

# %%
clean_records = silver_df.count()
print("Final Clean Records:", clean_records)
# Out:
# Final Clean Records: 358580

# %% [markdown]
# Null Counts Per Column

# %%
from pyspark.sql.functions import sum as spark_sum

null_counts = bronze_df.select([
    spark_sum(col(c).isNull().cast("int")).alias(c)
    for c in bronze_df.columns
])

null_counts.show()
# Out:
# +---------+---------+-----------+--------+-----------+---------+----------+-------+----+-----+
# |InvoiceNo|StockCode|Description|Quantity|InvoiceDate|UnitPrice|CustomerID|Country|year|month|
# +---------+---------+-----------+--------+-----------+---------+----------+-------+----+-----+
# |        0|        0|       1454|       0|          0|        0|    135080|      0|   0|    0|
# +---------+---------+-----------+--------+-----------+---------+----------+-------+----+-----+

# %% [markdown]
# ### Step 7 - Data Quality report

# %%
dq_report = spark.createDataFrame([
    ("Total Records Processed", total_records),
    ("Missing CustomerID Removed", missing_customer_count),
    ("Negative Quantity Removed", negative_qty_count),
    ("Cancelled Invoices Removed", cancelled_count),
    ("Invalid Price Removed", invalid_price_count),
    ("Extreme Price Outliers Removed", outlier_count),
    ("Duplicate Records Removed", duplicate_removed),
    ("Final Clean Records", clean_records)
], ["Metric", "Value"])

dq_report.show()
# Out:
# +--------------------+------+
# |              Metric| Value|
# +--------------------+------+
# |Total Records Pro...|541909|
# |Missing CustomerI...|135080|
# |Negative Quantity...|  8905|
# |Cancelled Invoice...|     0|
# |Invalid Price Rem...|    40|
# |Extreme Price Out...| 34356|
# |Duplicate Records...|  4948|
# | Final Clean Records|358580|
# +--------------------+------+

# %% [markdown]
# Export Data Quality Report

# %%
dq_report.toPandas().to_csv(
    BASE_PATH + "/reports/data_quality_report.csv",
    index=False
)

print("Data Quality Report Saved ✅")
# Out:
# Data Quality Report Saved ✅

# %%
# Define Silver Path (if not defined earlier)
SILVER_PATH = BASE_PATH + "/silver/"

# Write Silver Data
silver_df.write \
    .mode("overwrite") \
    .partitionBy("year", "month") \
    .parquet(SILVER_PATH)

print("Silver Layer Saved Successfully ✅")
# Out:
# Silver Layer Saved Successfully ✅

# %% [markdown]
# # TASK 3 – Feature Engineering

# %% [markdown]
# ### Step 1 — Revenue Calculation

# %%
from pyspark.sql.functions import col

feature_df = silver_df.withColumn(
    "Revenue",
    col("Quantity") * col("UnitPrice")
)

# %% [markdown]
# ### Step 2 — Time-Based Features

# %% [markdown]
# Feature 1: Hour

# %%
from pyspark.sql.functions import hour

feature_df = feature_df.withColumn(
    "Hour",
    hour("InvoiceDate")
)

# %% [markdown]
# Feature 2: Weekday

# %%
from pyspark.sql.functions import dayofweek

feature_df = feature_df.withColumn(
    "Weekday",
    dayofweek("InvoiceDate")
)

# %% [markdown]
# Feature 3: Month

# %%
from pyspark.sql.functions import month

feature_df = feature_df.withColumn(
    "Month",
    month("InvoiceDate")
)

# %% [markdown]
# ### Step 3 — Basket-Level Metrics

# %%
from pyspark.sql.functions import sum, count

basket_metrics = feature_df.groupBy("InvoiceNo") \
    .agg(
        sum("Revenue").alias("BasketRevenue"),
        count("StockCode").alias("ItemsPerBasket")
    )

# %% [markdown]
# Additional ItemsPerBasket

# %%
feature_df = feature_df.join(
    basket_metrics,
    on="InvoiceNo",
    how="left"
)

# %% [markdown]
# ### Step 4 — Customer RFM Features

# %%
from pyspark.sql.functions import max, datediff, current_date

rfm_df = feature_df.groupBy("CustomerID") \
    .agg(
        datediff(current_date(), max("InvoiceDate")).alias("Recency"),
        count("InvoiceNo").alias("Frequency"),
        sum("Revenue").alias("Monetary")
    )

# %% [markdown]
# ### Step 5 — Window-Based Feature

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank

window_spec = Window.orderBy(col("Monetary").desc())

rfm_df = rfm_df.withColumn(
    "CustomerRank",
    rank().over(window_spec)
)

# %% [markdown]
# ### Step 6 - This part we save that data into Gold Layer

# %%
GOLD_PATH = BASE_PATH + "/gold/"

feature_df.write \
    .mode("overwrite") \
    .partitionBy("year", "month") \
    .parquet(GOLD_PATH)

print("Feature Engineered Data Saved ✅")
# Out:
# Feature Engineered Data Saved ✅

# %% [markdown]
# # TASK 4 – MongoDB Data Modeling

# %% [markdown]
# ### Step 1 - Load Dataset

# %%
feature_df = spark.read.parquet("/content/drive/MyDrive/BigData_Assigenment02/gold")

# %% [markdown]
# ### Step 2 - Create MongoDB Collections

# %% [markdown]
# #### Collection 1 - fact_invoices

# %%
from pyspark.sql.functions import collect_list, struct, sum, first

fact_invoices = feature_df.groupBy(
    "InvoiceNo",
    "CustomerID",
    "InvoiceDate"
).agg(
    sum("Revenue").alias("TotalInvoiceRevenue"),
    collect_list(
        struct(
            "StockCode",
            "Description",
            "Quantity",
            "UnitPrice",
            "Revenue"
        )
    ).alias("line_items")
)

# %% [markdown]
# ***Schema Definition (fact_invoices)***
#
#
# {
#
#    _id: ObjectId,
#
#    Invoice: String,
#
#    CustomerID: Integer,
#
#    InvoiceDate: Date,
#
#    Country: String,
#
#    total_invoice_revenue: Double,
#
#    line_items: [
#
#       {
#         StockCode: String,
#         Description: String,
#         Quantity: Integer,
#         Price: Double,
#         revenue: Double
#       }
#      ]
#
# }

# %% [markdown]
# #### Collection 2 - dim_customers

# %%
from pyspark.sql.functions import when

dim_customers = rfm_df.withColumn(
    "CustomerSegment",
    when(rfm_df["Monetary"] >= 5000, "High Value")
    .when(rfm_df["Monetary"] >= 2000, "Medium Value")
    .otherwise("Low Value")
)

# %% [markdown]
# ***Schema Definition (dim_customers)***
#
# {
#
#   _id: ObjectId,
#
#   CustomerID: Integer,
#
#   recency: Integer,
#
#   frequency: Integer,
#
#   monetary: Double,
#
#   total_invoices: Integer,
#
#   total_revenue: Double,
#
#   customer_segment: String
#
# }

# %% [markdown]
# #### Collection 3 - dim_products

# %%
from pyspark.sql.functions import sum, collect_set

dim_products = feature_df.groupBy(
    "StockCode",
    "Description"
).agg(
    sum("Revenue").alias("TotalProductRevenue"),
    sum("Quantity").alias("TotalQuantitySold"),
    collect_set("Country").alias("CountriesSold")
)

# %% [markdown]
# ***Schema Definition (dim_products)***
#
# {
#
#   _id: ObjectId,
#
#   StockCode: String,
#
#   Description: String,
#
#   total_quantity_sold: Integer,
#
#   total_product_revenue: Double,
#
#   countries_sold: [String]
#
# }

# %% [markdown]
# # TASK 5 – MongoDB Indexing & Write Optimization

# %% [markdown]
# ### Step 1 - Write Gold Datasets to MongoDB

# %%
# Write fact_invoices
fact_invoices.write \
    .format("mongodb") \
    .mode("overwrite") \
    .option("spark.mongodb.database", "E-Commerce_Database") \
    .option("spark.mongodb.collection", "fact_invoices") \
    .save()

# Write dim_customers
dim_customers.write \
    .format("mongodb") \
    .mode("overwrite") \
    .option("spark.mongodb.database", "E-Commerce_Database") \
    .option("spark.mongodb.collection", "dim_customers") \
    .save()

# Write dim_products
dim_products.write \
    .format("mongodb") \
    .mode("overwrite") \
    .option("spark.mongodb.database", "E-Commerce_Database") \
    .option("spark.mongodb.collection", "dim_products") \
    .save()

print("All Gold datasets written successfully ✅") # Database already created using colab
# Out:
# All Gold datasets written successfully ✅

# %% [markdown]
# ### Step 3 - Creating Indexes on MongoDB Collections

# %%
from pymongo import MongoClient
from google.colab import userdata

# Ensure db client is active. This re-initializes it if needed.
mongo_uri = userdata.get("MONGO_URI")
client = MongoClient(mongo_uri)
db = client["E-Commerce_Database"]

# Index 1 — CustomerID (fact_invoices)
db.fact_invoices.create_index("CustomerID")
print("Index on fact_invoices.CustomerID created.")

# Index 2 - InvoiceDate (fact_invoices)
db.fact_invoices.create_index("InvoiceDate")
print("Index on fact_invoices.InvoiceDate created.")

# Index 3 — CustomerSegment (dim_customers)
db.dim_customers.create_index("CustomerSegment")
print("Index on dim_customers.CustomerSegment created.")

# Index 4 — StockCode (dim_products)
db.dim_products.create_index("StockCode")
print("Index on dim_products.StockCode created.")

print("All specified indexes created successfully ✅")
# Out:
# Index on fact_invoices.CustomerID created.
# Index on fact_invoices.InvoiceDate created.
# Index on dim_customers.CustomerSegment created.
# Index on dim_products.StockCode created.
# All specified indexes created successfully ✅

# %% [markdown]
# ### Step 4 - Demonstrate Query Performance Improvement

# %% [markdown]
# Test before index

# %%
import time

start = time.time()
list(db.fact_invoices.find({"CustomerID": 17850}))
end = time.time()

print("Query Time:", end - start, "seconds")
# Out:
# Query Time: 0.46863317489624023 seconds

# %% [markdown]
# verify index usage

# %%
db.fact_invoices.find({"CustomerID": 17850}).explain()
# Out:
# {'explainVersion': '1',
#  'queryPlanner': {'namespace': 'E-Commerce_Database.fact_invoices',
#   'parsedQuery': {'CustomerID': {'$eq': 17850}},
#   'indexFilterSet': False,
#   'queryHash': 'B6E1B21F',
#   'planCacheShapeHash': 'B6E1B21F',
#   'planCacheKey': '445467B7',
#   'optimizationTimeMillis': 0,
#   'maxIndexedOrSolutionsReached': False,
#   'maxIndexedAndSolutionsReached': False,
#   'maxScansToExplodeReached': False,
#   'prunedSimilarIndexes': False,
#   'winningPlan': {'isCached': False,
#    'stage': 'FETCH',
#    'inputStage': {'stage': 'IXSCAN',
#     'keyPattern': {'CustomerID': 1},
#     'indexName': 'CustomerID_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'CustomerID': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'CustomerID': ['[17850, 17850]']}}},
#   'rejectedPlans': []},
#  'executionStats': {'executionSuccess': True,
#   'nReturned': 34,
#   'executionTimeMillis': 0,
#   'totalKeysExamined': 34,
#   'totalDocsExamined': 34,
#   'executionStages': {'isCached': False,
#    'stage': 'FETCH',
#    'nReturned': 34,
#    'executionTimeMillisEstimate': 0,
#    'works': 35,
#    'advanced': 34,
#    'needTime': 0,
#    'needYield': 0,
#    'saveState': 0,
#    'restoreState': 0,
#    'isEOF': 1,
#    'docsExamined': 34,
#    'alreadyHasObj': 0,
#    'inputStage': {'stage': 'IXSCAN',
#     'nReturned': 34,
#     'executionTimeMillisEstimate': 0,
#     'works': 35,
#     'advanced': 34,
#     'needTime': 0,
#     'needYield': 0,
#     'saveState': 0,
#     'restoreState': 0,
#     'isEOF': 1,
#     'keyPattern': {'CustomerID': 1},
#     'indexName': 'CustomerID_1',
#     'isMultiKey': False,
#     'multiKeyPaths': {'CustomerID': []},
#     'isUnique': False,
#     'isSparse': False,
#     'isPartial': False,
#     'indexVersion': 2,
#     'direction': 'forward',
#     'indexBounds': {'CustomerID': ['[17850, 17850]']},
#     'keysExamined': 34,
#     'seeks': 1,
#     'dupsTested': 0,
#     'dupsDropped': 0}},
#   'allPlansExecution': []},
#  'queryShapeHash': '7FAEB6311C6123B0CDB04F4584C5F38F639535CC658033D42FB09B56BC81DEA9',
#  'command': {'find': 'fact_invoices',
#   'filter': {'CustomerID': 17850},
#   '$db': 'E-Commerce_Database'},
#  'serverInfo': {'host': 'ac-bzslynf-shard-00-02.dn4arlu.mongodb.net',
#   'port': 27017,
#   'version': '8.0.19',
#   'gitVersion': 'cc1adb6b0875cc3003854ac2489818e459686f0b'},
#  'serverParameters': {'internalQueryFacetBufferSizeBytes': 104857600,
#   'internalQueryFacetMaxOutputDocSizeBytes': 104857600,
#   'internalLookupStageIntermediateDocumentMaxSizeBytes': 16793600,
#   'internalDocumentSourceGroupMaxMemoryBytes': 104857600,
#   'internalQueryMaxBlockingSortMemoryUsageBytes': 33554432,
#   'internalQueryProhibitBlockingMergeOnMongoS': 0,
#   'internalQueryMaxAddToSetBytes': 104857600,
#   'internalDocumentSourceSetWindowFieldsMaxMemoryBytes': 104857600,
#   'internalQueryFrameworkControl': 'trySbeRestricted',
#   'internalQueryPlannerIgnoreIndexWithCollationForRegex': 1},
#  'ok': 1.0,
#  '$clusterTime': {'clusterTime': Timestamp(1771480940, 15),
#   'signature': {'hash': b'$\x86\x9e\xa4hg&f7\xfa\xfa\xc8\xb5\xdd\xb5\xe0\xb5\xa2\x1e?',
#    'keyId': 7557397795179593730}},
#  'operationTime': Timestamp(1771480940, 15)}

# %% [markdown]
# # TASK 6 – Analytics & Insights

# %% [markdown]
# ### Part A - 5 Spark-based analytics queries

# %% [markdown]
# #### Monthly Revenue Trends

# %%
from pyspark.sql.functions import sum, month, year

monthly_revenue = feature_df \
    .groupBy(year("InvoiceDate").alias("Year"),
             month("InvoiceDate").alias("Month")) \
    .agg(sum("Revenue").alias("TotalRevenue")) \
    .orderBy("Year", "Month")

monthly_revenue.show()
# Out:
# +----+-----+------------------+
# |Year|Month|      TotalRevenue|
# +----+-----+------------------+
# |2010|   12| 480348.9500000139|
# |2011|    1| 495617.7300000107|
# |2011|    2| 379688.2800000083|
# |2011|    3| 492847.0500000031|
# |2011|    4| 394154.6910000067|
# |2011|    5| 563858.3699999995|
# |2011|    6| 532562.6000000084|
# |2011|    7| 518686.8710000066|
# |2011|    8| 564883.8500000046|
# |2011|    9| 849232.1320000029|
# |2011|   10| 881896.7099999939|
# |2011|   11|1013999.2999999907|
# |2011|   12|477047.77000000223|
# +----+-----+------------------+

# %% [markdown]
# #### Top Customers by Spend

# %%
top_customers = feature_df \
    .groupBy("CustomerID") \
    .agg(sum("Revenue").alias("TotalSpend")) \
    .orderBy("TotalSpend", ascending=False) \
    .limit(10)

top_customers.show()
# Out:
# +----------+------------------+
# |CustomerID|        TotalSpend|
# +----------+------------------+
# |     14646|262583.41999999946|
# |     18102|221190.81000000006|
# |     17450| 180952.7299999999|
# |     16446|          168472.5|
# |     12415|113631.68000000001|
# |     14911| 112862.2499999998|
# |     14156| 97088.98000000004|
# |     17511| 86658.71999999994|
# |     12346|           77183.6|
# |     16029| 71848.28999999998|
# +----------+------------------+

# %% [markdown]
# #### Top Products by Revenue

# %%
top_products = feature_df \
    .groupBy("StockCode", "Description") \
    .agg(sum("Revenue").alias("TotalRevenue")) \
    .orderBy("TotalRevenue", ascending=False) \
    .limit(10)

top_products.show()
# Out:
# +---------+--------------------+------------------+
# |StockCode|         Description|      TotalRevenue|
# +---------+--------------------+------------------+
# |    23843|PAPER CRAFT , LIT...|          168469.6|
# |   85123A|WHITE HANGING HEA...|100392.09999999966|
# |   85099B|JUMBO BAG RED RET...| 85040.54000000026|
# |    23166|MEDIUM CERAMIC TO...|          81416.73|
# |    47566|       PARTY BUNTING| 68655.75000000003|
# |    84879|ASSORTED COLOUR B...|56413.030000000515|
# |    23084|  RABBIT NIGHT LIGHT| 51251.24000000005|
# |    79321|       CHILLI LIGHTS| 46078.20999999997|
# |    22086|PAPER CHAIN KIT 5...|42584.130000000165|
# |    21137|BLACK RECORD COVE...|39045.800000000025|
# +---------+--------------------+------------------+

# %% [markdown]
# #### Country-Level Sales Analysis

# %%
country_sales = feature_df \
    .groupBy("Country") \
    .agg(sum("Revenue").alias("TotalRevenue")) \
    .orderBy("TotalRevenue", ascending=False)

country_sales.show()
# Out:
# +---------------+------------------+
# |        Country|      TotalRevenue|
# +---------------+------------------+
# | United Kingdom| 6334870.804000116|
# |    Netherlands| 266830.6399999994|
# |           EIRE|213121.38999999964|
# |        Germany|174099.74999999977|
# |         France|162311.06000000017|
# |      Australia|126161.75999999994|
# |          Spain|47124.960000000094|
# |    Switzerland|45040.950000000084|
# |         Sweden|36568.429999999986|
# |          Japan|35897.469999999994|
# |        Belgium| 31353.25000000003|
# |         Norway|27446.640000000003|
# |       Portugal|24435.969999999987|
# |        Finland| 16361.28000000001|
# |Channel Islands|15050.439999999997|
# |        Denmark|13375.439999999993|
# |          Italy|13127.490000000005|
# |         Cyprus| 9497.159999999996|
# |      Singapore| 7928.389999999997|
# |        Austria| 7658.830000000002|
# +---------------+------------------+
# only showing top 20 rows

# %% [markdown]
# #### Return / Cancellation Patterns

# %%
returns_analysis = feature_df \
    .filter(feature_df["Quantity"] < 0) \
    .groupBy("Country") \
    .count()

returns_analysis.show()
# Out:
# +-------+-----+
# |Country|count|
# +-------+-----+
# +-------+-----+

# %% [markdown]
# ### Part B - MongoDB Aggregation Pipelines

# %%
from pymongo import MongoClient
from google.colab import userdata

mongo_uri = userdata.get("MONGO_URI")
client = MongoClient(mongo_uri)
db = client["E-Commerce_Database"]

# %% [markdown]
# #### Monthly Revenue (fact_invoices)

# %%
pipeline = [
    {
        "$group": {
            "_id": {
                "year": {"$year": "$InvoiceDate"},
                "month": {"$month": "$InvoiceDate"}
            },
            "TotalRevenue": {"$sum": "$TotalInvoiceRevenue"}
        }
    },
    {"$sort": {"_id.year": 1, "_id.month": 1}}
]

list(db.fact_invoices.aggregate(pipeline))
# Out:
# [{'_id': {'year': 2010, 'month': 12}, 'TotalRevenue': 480348.95},
#  {'_id': {'year': 2011, 'month': 1}, 'TotalRevenue': 495617.73},
#  {'_id': {'year': 2011, 'month': 2}, 'TotalRevenue': 379688.28},
#  {'_id': {'year': 2011, 'month': 3}, 'TotalRevenue': 492847.05},
#  {'_id': {'year': 2011, 'month': 4}, 'TotalRevenue': 394154.691},
#  {'_id': {'year': 2011, 'month': 5}, 'TotalRevenue': 563858.37},
#  {'_id': {'year': 2011, 'month': 6}, 'TotalRevenue': 532562.6},
#  {'_id': {'year': 2011, 'month': 7}, 'TotalRevenue': 518686.871},
#  {'_id': {'year': 2011, 'month': 8}, 'TotalRevenue': 564883.85},
#  {'_id': {'year': 2011, 'month': 9}, 'TotalRevenue': 849232.132},
#  {'_id': {'year': 2011, 'month': 10}, 'TotalRevenue': 881896.71},
#  {'_id': {'year': 2011, 'month': 11}, 'TotalRevenue': 1013999.3},
#  {'_id': {'year': 2011, 'month': 12}, 'TotalRevenue': 477047.77}]

# %% [markdown]
# #### Top Customers (dim_customers)

# %%
pipeline = [
    {"$sort": {"Monetary": -1}},
    {"$limit": 10}
]

list(db.dim_customers.aggregate(pipeline))
# Out:
# [{'_id': ObjectId('6996a74105884627736ccd3e'),
#   'CustomerID': 14646,
#   'Recency': 5187,
#   'Frequency': 1944,
#   'Monetary': 262583.4199999997,
#   'CustomerRank': 1,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd3f'),
#   'CustomerID': 18102,
#   'Recency': 5186,
#   'Frequency': 400,
#   'Monetary': 221190.81,
#   'CustomerRank': 2,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd40'),
#   'CustomerID': 17450,
#   'Recency': 5194,
#   'Frequency': 296,
#   'Monetary': 180952.73,
#   'CustomerRank': 3,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd41'),
#   'CustomerID': 16446,
#   'Recency': 5186,
#   'Frequency': 3,
#   'Monetary': 168472.5,
#   'CustomerRank': 4,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd42'),
#   'CustomerID': 12415,
#   'Recency': 5210,
#   'Frequency': 676,
#   'Monetary': 113631.67999999998,
#   'CustomerRank': 5,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd43'),
#   'CustomerID': 14911,
#   'Recency': 5187,
#   'Frequency': 4885,
#   'Monetary': 112862.24999999984,
#   'CustomerRank': 6,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd44'),
#   'CustomerID': 14156,
#   'Recency': 5195,
#   'Frequency': 1234,
#   'Monetary': 97088.98000000005,
#   'CustomerRank': 7,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd45'),
#   'CustomerID': 17511,
#   'Recency': 5188,
#   'Frequency': 910,
#   'Monetary': 86658.71999999997,
#   'CustomerRank': 8,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd46'),
#   'CustomerID': 12346,
#   'Recency': 5511,
#   'Frequency': 1,
#   'Monetary': 77183.6,
#   'CustomerRank': 9,
#   'CustomerSegment': 'High Value'},
#  {'_id': ObjectId('6996a74105884627736ccd47'),
#   'CustomerID': 16029,
#   'Recency': 5224,
#   'Frequency': 231,
#   'Monetary': 71848.29,
#   'CustomerRank': 10,
#   'CustomerSegment': 'High Value'}]

# %% [markdown]
# #### Top Products by Revenue

# %%
pipeline = [
    {"$sort": {"TotalProductRevenue": -1}},
    {"$limit": 10}
]

list(db.dim_products.aggregate(pipeline))
# Out:
# [{'_id': ObjectId('6996a76005884627736ce791'),
#   'StockCode': '23843',
#   'Description': 'PAPER CRAFT , LITTLE BIRDIE',
#   'TotalProductRevenue': 168469.6,
#   'TotalQuantitySold': 80995,
#   'CountriesSold': ['United Kingdom']},
#  {'_id': ObjectId('6996a76405884627736ceac1'),
#   'StockCode': '85123A',
#   'Description': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'TotalProductRevenue': 100392.09999999964,
#   'TotalQuantitySold': 36706,
#   'CountriesSold': ['Portugal',
#    'Italy',
#    'EIRE',
#    'Finland',
#    'Germany',
#    'Switzerland',
#    'Malta',
#    'Spain',
#    'Singapore',
#    'Netherlands',
#    'Cyprus',
#    'France',
#    'Channel Islands',
#    'Australia',
#    'United Kingdom',
#    'Israel']},
#  {'_id': ObjectId('6996a76405884627736ceab2'),
#   'StockCode': '85099B',
#   'Description': 'JUMBO BAG RED RETROSPOT',
#   'TotalProductRevenue': 85040.54000000026,
#   'TotalQuantitySold': 46078,
#   'CountriesSold': ['Portugal',
#    'Italy',
#    'EIRE',
#    'Finland',
#    'Austria',
#    'Germany',
#    'RSA',
#    'Switzerland',
#    'Spain',
#    'Sweden',
#    'Singapore',
#    'Netherlands',
#    'Belgium',
#    'Cyprus',
#    'France',
#    'Channel Islands',
#    'Australia',
#    'Norway',
#    'United Kingdom',
#    'USA']},
#  {'_id': ObjectId('6996a75e05884627736ce5c3'),
#   'StockCode': '23166',
#   'Description': 'MEDIUM CERAMIC TOP STORAGE JAR',
#   'TotalProductRevenue': 81416.73,
#   'TotalQuantitySold': 77916,
#   'CountriesSold': ['EIRE',
#    'Norway',
#    'Australia',
#    'Poland',
#    'Germany',
#    'United Kingdom',
#    'Switzerland',
#    'Netherlands',
#    'Israel',
#    'USA']},
#  {'_id': ObjectId('6996a76205884627736ce851'),
#   'StockCode': '47566',
#   'Description': 'PARTY BUNTING',
#   'TotalProductRevenue': 68655.75000000003,
#   'TotalQuantitySold': 15267,
#   'CountriesSold': ['EIRE',
#    'Finland',
#    'Austria',
#    'RSA',
#    'Germany',
#    'Switzerland',
#    'Spain',
#    'Singapore',
#    'Netherlands',
#    'Lebanon',
#    'Belgium',
#    'Cyprus',
#    'France',
#    'Channel Islands',
#    'Australia',
#    'Norway',
#    'Denmark',
#    'United Kingdom',
#    'Japan',
#    'Israel']},
#  {'_id': ObjectId('6996a76405884627736cea18'),
#   'StockCode': '84879',
#   'Description': 'ASSORTED COLOUR BIRD ORNAMENT',
#   'TotalProductRevenue': 56413.03000000051,
#   'TotalQuantitySold': 35263,
#   'CountriesSold': ['Portugal',
#    'Italy',
#    'EIRE',
#    'Austria',
#    'Germany',
#    'Canada',
#    'Switzerland',
#    'Spain',
#    'Netherlands',
#    'Belgium',
#    'Cyprus',
#    'France',
#    'Channel Islands',
#    'Norway',
#    'United Kingdom',
#    'Unspecified']},
#  {'_id': ObjectId('6996a75e05884627736ce56b'),
#   'StockCode': '23084',
#   'Description': 'RABBIT NIGHT LIGHT',
#   'TotalProductRevenue': 51251.240000000034,
#   'TotalQuantitySold': 27153,
#   'CountriesSold': ['Portugal',
#    'Italy',
#    'EIRE',
#    'Finland',
#    'Poland',
#    'Germany',
#    'Switzerland',
#    'Greece',
#    'Spain',
#    'Sweden',
#    'Netherlands',
#    'Belgium',
#    'France',
#    'Australia',
#    'Norway',
#    'Denmark',
#    'United Kingdom',
#    'Japan',
#    'Iceland']},
#  {'_id': ObjectId('6996a76205884627736ce8f0'),
#   'StockCode': '79321',
#   'Description': 'CHILLI LIGHTS',
#   'TotalProductRevenue': 46078.20999999996,
#   'TotalQuantitySold': 9631,
#   'CountriesSold': ['Portugal', 'EIRE', 'Norway', 'United Kingdom', 'Spain']},
#  {'_id': ObjectId('6996a75a05884627736ce1db'),
#   'StockCode': '22086',
#   'Description': "PAPER CHAIN KIT 50'S CHRISTMAS ",
#   'TotalProductRevenue': 42584.130000000165,
#   'TotalQuantitySold': 15591,
#   'CountriesSold': ['France',
#    'Channel Islands',
#    'EIRE',
#    'Australia',
#    'Germany',
#    'United Kingdom',
#    'Switzerland',
#    'Spain',
#    'Singapore',
#    'Netherlands']},
#  {'_id': ObjectId('6996a75705884627736cdf8b'),
#   'StockCode': '21137',
#   'Description': 'BLACK RECORD COVER FRAME',
#   'TotalProductRevenue': 39045.800000000025,
#   'TotalQuantitySold': 11401,
#   'CountriesSold': ['France',
#    'EIRE',
#    'Australia',
#    'Austria',
#    'Germany',
#    'United Kingdom',
#    'Spain']}]

# %% [markdown]
# #### Country Distribution

# %%
pipeline = [
    {"$unwind": "$CountriesSold"},
    {
        "$group": {
            "_id": "$CountriesSold",
            "ProductCount": {"$sum": 1}
        }
    },
    {"$sort": {"ProductCount": -1}}
]

list(db.dim_products.aggregate(pipeline))
# Out:
# [{'_id': 'United Kingdom', 'ProductCount': 3596},
#  {'_id': 'EIRE', 'ProductCount': 1817},
#  {'_id': 'Germany', 'ProductCount': 1561},
#  {'_id': 'France', 'ProductCount': 1414},
#  {'_id': 'Spain', 'ProductCount': 990},
#  {'_id': 'Switzerland', 'ProductCount': 864},
#  {'_id': 'Netherlands', 'ProductCount': 744},
#  {'_id': 'Belgium', 'ProductCount': 711},
#  {'_id': 'Portugal', 'ProductCount': 647},
#  {'_id': 'Australia', 'ProductCount': 569},
#  {'_id': 'Norway', 'ProductCount': 532},
#  {'_id': 'Cyprus', 'ProductCount': 427},
#  {'_id': 'Finland', 'ProductCount': 420},
#  {'_id': 'Italy', 'ProductCount': 411},
#  {'_id': 'Channel Islands', 'ProductCount': 353},
#  {'_id': 'Austria', 'ProductCount': 282},
#  {'_id': 'Sweden', 'ProductCount': 252},
#  {'_id': 'Denmark', 'ProductCount': 232},
#  {'_id': 'Japan', 'ProductCount': 211},
#  {'_id': 'Israel', 'ProductCount': 197},
#  {'_id': 'Unspecified', 'ProductCount': 190},
#  {'_id': 'Poland', 'ProductCount': 171},
#  {'_id': 'Singapore', 'ProductCount': 167},
#  {'_id': 'USA', 'ProductCount': 157},
#  {'_id': 'Canada', 'ProductCount': 136},
#  {'_id': 'Greece', 'ProductCount': 123},
#  {'_id': 'Iceland', 'ProductCount': 100},
#  {'_id': 'Malta', 'ProductCount': 86},
#  {'_id': 'United Arab Emirates', 'ProductCount': 62},
#  {'_id': 'RSA', 'ProductCount': 45},
#  {'_id': 'European Community', 'ProductCount': 41},
#  {'_id': 'Lebanon', 'ProductCount': 33},
#  {'_id': 'Lithuania', 'ProductCount': 29},
#  {'_id': 'Brazil', 'ProductCount': 25},
#  {'_id': 'Czech Republic', 'ProductCount': 24},
#  {'_id': 'Bahrain', 'ProductCount': 13},
#  {'_id': 'Saudi Arabia', 'ProductCount': 9}]

# %% [markdown]
# #### Customer Segment Distribution

# %%
pipeline = [
    {
        "$group": {
            "_id": "$CustomerSegment",
            "Count": {"$sum": 1}
        }
    }
]

list(db.dim_customers.aggregate(pipeline))
# Out:
# [{'_id': 'High Value', 'Count': 220},
#  {'_id': 'Medium Value', 'Count': 530},
#  {'_id': 'Low Value', 'Count': 3556}]

# %% [markdown]
# # TASK 7 – Performance Optimization

# %% [markdown]
# ### Partitioning Strategy (Shuffle Optimization)

# %% [markdown]
# Before Optimization

# %%
feature_df.rdd.getNumPartitions()
# Out:
# 2

# %% [markdown]
# Apply Repartitioning by CustomerID

# %%
optimized_df = feature_df.repartition(8, "CustomerID")

optimized_df.rdd.getNumPartitions()
# Out:
# 8

# %% [markdown]
# ### Caching & Persistence

# %% [markdown]
# Without Cache

# %%
feature_df.groupBy("Country").count().show()
feature_df.groupBy("CustomerID").count().show()
# Out:
# +------------------+-----+
# |           Country|count|
# +------------------+-----+
# |            Sweden|  419|
# |         Singapore|  202|
# |           Germany| 7955|
# |               RSA|   45|
# |            France| 7388|
# |            Greece|  128|
# |European Community|   47|
# |           Belgium| 1737|
# |           Finland|  582|
# |             Malta|   93|
# |       Unspecified|  212|
# |             Italy|  626|
# |              EIRE| 6261|
# |            Norway|  930|
# |             Spain| 2145|
# |           Denmark|  343|
# |           Iceland|  175|
# |            Israel|  218|
# |   Channel Islands|  577|
# |               USA|  172|
# +------------------+-----+
# only showing top 20 rows
#
# +----------+-----+
# |CustomerID|count|
# +----------+-----+
# |     17389|  142|
# |     15619|    2|
# |     13623|   67|
# |     16386|   78|
# |     13832|    3|
# |     13285|  178|
# |     15727|  284|
# |     15790|   29|
# |     15957|   40|
# |     12940|   76|
# |     16861|    6|
# |     17420|   25|
# |     17679|   24|
# |     16574|   27|
# |     16503|   66|
# |     14450|   40|
# |     18024|   19|
# |     14570|   26|
# |     12471|  410|
# |     16500|   10|
# +----------+-----+
# only showing top 20 rows

# %% [markdown]
# Apply Cache

# %%
feature_df.cache()

feature_df.groupBy("Country").count().show()
feature_df.groupBy("CustomerID").count().show()
# Out:
# +------------------+-----+
# |           Country|count|
# +------------------+-----+
# |            Sweden|  419|
# |         Singapore|  202|
# |           Germany| 7955|
# |               RSA|   45|
# |            France| 7388|
# |            Greece|  128|
# |European Community|   47|
# |           Belgium| 1737|
# |           Finland|  582|
# |             Malta|   93|
# |       Unspecified|  212|
# |             Italy|  626|
# |              EIRE| 6261|
# |            Norway|  930|
# |             Spain| 2145|
# |           Denmark|  343|
# |           Iceland|  175|
# |            Israel|  218|
# |   Channel Islands|  577|
# |               USA|  172|
# +------------------+-----+
# only showing top 20 rows
#
# +----------+-----+
# |CustomerID|count|
# +----------+-----+
# |     17389|  142|
# |     15619|    2|
# |     13623|   67|
# |     16386|   78|
# |     13832|    3|
# |     13285|  178|
# |     15727|  284|
# |     15790|   29|
# |     15957|   40|
# |     12940|   76|
# |     16861|    6|
# |     17420|   25|
# |     17679|   24|
# |     16574|   27|
# |     16503|   66|
# |     14450|   40|
# |     18024|   19|
# |     14570|   26|
# |     12471|  410|
# |     16500|   10|
# +----------+-----+
# only showing top 20 rows

# %% [markdown]
# ### Broadcast Join Optimization

# %% [markdown]
# Without Broadcast

# %%
joined_df = feature_df.join(dim_customers, "CustomerID")
joined_df.show()
# Out:
# +----------+---------+---------+--------------------+--------+-------------------+---------+--------------+------------------+----+-------+------------------+--------------+----+-----+-------+---------+------------------+------------+---------------+
# |CustomerID|InvoiceNo|StockCode|         Description|Quantity|        InvoiceDate|UnitPrice|       Country|           Revenue|Hour|Weekday|     BasketRevenue|ItemsPerBasket|year|month|Recency|Frequency|          Monetary|CustomerRank|CustomerSegment|
# +----------+---------+---------+--------------------+--------+-------------------+---------+--------------+------------------+----+-------+------------------+--------------+----+-----+-------+---------+------------------+------------+---------------+
# |     17389|   575683|    22666|RECIPE BOX PANTRY...|     192|2011-11-10 15:51:00|     2.55|United Kingdom|489.59999999999997|  15|      5|2723.5200000000004|            15|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   575683|   84029E|RED WOOLLY HOTTIE...|      30|2011-11-10 15:51:00|     3.75|United Kingdom|             112.5|  15|      5|2723.5200000000004|            15|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   575683|    21137|BLACK RECORD COVE...|      48|2011-11-10 15:51:00|     3.39|United Kingdom|            162.72|  15|      5|2723.5200000000004|            15|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   575683|    22138|BAKING SET 9 PIEC...|      36|2011-11-10 15:51:00|     4.25|United Kingdom|             153.0|  15|      5|2723.5200000000004|            15|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   575683|   84029G|KNITTED UNION FLA...|      60|2011-11-10 15:51:00|     3.75|United Kingdom|             225.0|  15|      5|2723.5200000000004|            15|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   575683|    21588|RETROSPOT GIANT T...|     144|2011-11-10 15:51:00|      2.1|United Kingdom|302.40000000000003|  15|      5|2723.5200000000004|            15|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   575683|    22960|JAM MAKING SET WI...|      36|2011-11-10 15:51:00|     3.75|United Kingdom|             135.0|  15|      5|2723.5200000000004|            15|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     15619|   579257|    23681|LUNCH BAG RED VIN...|     100|2011-11-29 08:14:00|     1.45|United Kingdom|             145.0|   8|      3|244.60000000000002|             2|2011|   11|   5196|        2|244.60000000000002|        3258|      Low Value|
# |     17389|   573749|    84380|SET OF 3 BUTTERFL...|      12|2011-11-01 09:26:00|     1.25|United Kingdom|              15.0|   9|      3|            154.32|             8|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   573749|   84970L|SINGLE HEART ZINC...|      12|2011-11-01 09:26:00|     1.04|United Kingdom|             12.48|   9|      3|            154.32|             8|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   573749|    21466|RED FLOWER CROCHE...|       6|2011-11-01 09:26:00|     2.95|United Kingdom|17.700000000000003|   9|      3|            154.32|             8|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   573749|   84970S|HANGING HEART ZIN...|      12|2011-11-01 09:26:00|     0.72|United Kingdom|              8.64|   9|      3|            154.32|             8|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   573749|    22224|WHITE LOVEBIRD LA...|       6|2011-11-01 09:26:00|     2.55|United Kingdom|15.299999999999999|   9|      3|            154.32|             8|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     17389|   578821|    22617|BAKING SET SPACEB...|      50|2011-11-25 13:59:00|     4.25|United Kingdom|             212.5|  13|      6|             242.0|             2|2011|   11|   5186|      142|19642.079999999998|          39|     High Value|
# |     13623|   575258|   90161A|ANT COPPER RED BO...|       1|2011-11-09 12:00:00|     4.95|United Kingdom|              4.95|  12|      4|            188.57|            15|2011|   11|   5216|       67|438.84000000000003|        2465|      Low Value|
# |     13623|   575258|    22555|PLASTERS IN TIN S...|       1|2011-11-09 12:00:00|     1.65|United Kingdom|              1.65|  12|      4|            188.57|            15|2011|   11|   5216|       67|438.84000000000003|        2465|      Low Value|
# |     13623|   575258|    23215|JINGLE BELL HEART...|       6|2011-11-09 12:00:00|     2.08|United Kingdom|             12.48|  12|      4|            188.57|            15|2011|   11|   5216|       67|438.84000000000003|        2465|      Low Value|
# |     13623|   575258|    21591|COSY HOUR CIGAR B...|       1|2011-11-09 12:00:00|     1.25|United Kingdom|              1.25|  12|      4|            188.57|            15|2011|   11|   5216|       67|438.84000000000003|        2465|      Low Value|
# |     13623|   575258|    21811|HANGING HEART WIT...|      12|2011-11-09 12:00:00|     0.39|United Kingdom|              4.68|  12|      4|            188.57|            15|2011|   11|   5216|       67|438.84000000000003|        2465|      Low Value|
# |     13623|   575258|   84279P|CHERRY BLOSSOM  D...|       1|2011-11-09 12:00:00|     3.75|United Kingdom|              3.75|  12|      4|            188.57|            15|2011|   11|   5216|       67|438.84000000000003|        2465|      Low Value|
# +----------+---------+---------+--------------------+--------+-------------------+---------+--------------+------------------+----+-------+------------------+--------------+----+-----+-------+---------+------------------+------------+---------------+
# only showing top 20 rows

# %% [markdown]
# With Broadcast

# %%
from pyspark.sql.functions import broadcast

optimized_join = feature_df.join(
    broadcast(dim_customers),
    "CustomerID"
)

optimized_join.show()
# Out:
# +----------+---------+---------+--------------------+--------+-------------------+---------+--------------+------------------+----+-------+------------------+--------------+----+-----+-------+---------+------------------+------------+---------------+
# |CustomerID|InvoiceNo|StockCode|         Description|Quantity|        InvoiceDate|UnitPrice|       Country|           Revenue|Hour|Weekday|     BasketRevenue|ItemsPerBasket|year|month|Recency|Frequency|          Monetary|CustomerRank|CustomerSegment|
# +----------+---------+---------+--------------------+--------+-------------------+---------+--------------+------------------+----+-------+------------------+--------------+----+-----+-------+---------+------------------+------------+---------------+
# |     17160|   575091|    22579|WOODEN TREE CHRIS...|      24|2011-11-08 14:05:00|     0.29|United Kingdom| 6.959999999999999|  14|      3| 516.8499999999999|            38|2011|   11|   5217|      226|3471.5299999999997|         374|   Medium Value|
# |     17561|   577511|    23344|JUMBO BAG 50'S CH...|       2|2011-11-20 12:53:00|     2.08|United Kingdom|              4.16|  12|      1|            152.62|            44|2011|   11|   5205|       44|            152.62|        3732|      Low Value|
# |     13174|   578292|    22910|PAPER CHAIN KIT V...|       3|2011-11-23 14:35:00|     2.95|United Kingdom| 8.850000000000001|  14|      4|498.46000000000004|            58|2011|   11|   5202|      253|           2057.12|         723|   Medium Value|
# |     13668|   577022|    22577|WOODEN HEART CHRI...|       6|2011-11-17 12:42:00|     0.29|United Kingdom|1.7399999999999998|  12|      5|             321.6|            37|2011|   11|   5188|      424| 5791.930000000002|         169|     High Value|
# |     13174|   578292|    23273|HEART T-LIGHT HOL...|       6|2011-11-23 14:35:00|     1.65|United Kingdom| 9.899999999999999|  14|      4|498.46000000000004|            58|2011|   11|   5202|      253|           2057.12|         723|   Medium Value|
# |     13174|   578292|    22155|STAR DECORATION R...|      18|2011-11-23 14:35:00|     0.42|United Kingdom|              7.56|  14|      4|498.46000000000004|            58|2011|   11|   5202|      253|           2057.12|         723|   Medium Value|
# |     14902|   576112|   84997B|CHILDRENS CUTLERY...|       4|2011-11-14 10:34:00|     4.15|United Kingdom|              16.6|  10|      2|299.65999999999997|            18|2011|   11|   5211|       18|299.65999999999997|        2996|      Low Value|
# |     12920|   578057|    21481|FAWN BLUE HOT WAT...|       1|2011-11-22 15:05:00|     3.75|United Kingdom|              3.75|  15|      3|            120.93|            24|2011|   11|   5203|       24|            120.93|        3908|      Low Value|
# |     17160|   575091|    22952|60 CAKE CASES VIN...|      24|2011-11-08 14:05:00|     0.55|United Kingdom|13.200000000000001|  14|      3| 516.8499999999999|            38|2011|   11|   5217|      226|3471.5299999999997|         374|   Medium Value|
# |     13668|   577022|    82482|WOODEN PICTURE FR...|       6|2011-11-17 12:42:00|     2.95|United Kingdom|17.700000000000003|  12|      5|             321.6|            37|2011|   11|   5188|      424| 5791.930000000002|         169|     High Value|
# |     17561|   577511|    22565|FELTCRAFT HAIRBAN...|       1|2011-11-20 12:53:00|     0.85|United Kingdom|              0.85|  12|      1|            152.62|            44|2011|   11|   5205|       44|            152.62|        3732|      Low Value|
# |     17160|   575091|    22082|RIBBON REEL STRIP...|      10|2011-11-08 14:05:00|     1.65|United Kingdom|              16.5|  14|      3| 516.8499999999999|            38|2011|   11|   5217|      226|3471.5299999999997|         374|   Medium Value|
# |     16024|   578941|    21977|PACK OF 60 PINK P...|       1|2011-11-27 13:26:00|     0.55|United Kingdom|              0.55|  13|      1|            251.03|            63|2011|   11|   5198|       63|            251.03|        3233|      Low Value|
# |     16024|   578941|    21200|MULTICOLOUR HONEY...|       2|2011-11-27 13:26:00|     1.65|United Kingdom|               3.3|  13|      1|            251.03|            63|2011|   11|   5198|       63|            251.03|        3233|      Low Value|
# |     14902|   576112|    22863|  SOAP DISH BROCANTE|       8|2011-11-14 10:34:00|     2.95|United Kingdom|              23.6|  10|      2|299.65999999999997|            18|2011|   11|   5211|       18|299.65999999999997|        2996|      Low Value|
# |     13668|   577022|    20894|HANGING BAUBLE T-...|       4|2011-11-17 12:42:00|     2.95|United Kingdom|              11.8|  12|      5|             321.6|            37|2011|   11|   5188|      424| 5791.930000000002|         169|     High Value|
# |     12670|   575671|    22992|REVOLVER WOODEN R...|      24|2011-11-10 15:03:00|     1.95|        France|              46.8|  15|      5|            484.26|            17|2011|   11|   5196|       83|           2499.55|         567|   Medium Value|
# |     16024|   578941|    21976|PACK OF 60 MUSHRO...|       2|2011-11-27 13:26:00|     0.55|United Kingdom|               1.1|  13|      1|            251.03|            63|2011|   11|   5198|       63|            251.03|        3233|      Low Value|
# |     17561|   577511|    21429|RED GINGHAM ROSE ...|       1|2011-11-20 12:53:00|     1.95|United Kingdom|              1.95|  12|      1|            152.62|            44|2011|   11|   5205|       44|            152.62|        3732|      Low Value|
# |     12388|   578459|    22576|SWALLOW WOODEN CH...|      20|2011-11-24 12:30:00|     0.85|     Australia|              17.0|  12|      5|286.40000000000003|             8|2011|   11|   5201|       99|           2713.76|         514|   Medium Value|
# +----------+---------+---------+--------------------+--------+-------------------+---------+--------------+------------------+----+-------+------------------+--------------+----+-----+-------+---------+------------------+------------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### Create a table for optimizer

# %%
import time
from pyspark.sql.functions import broadcast

print("TASK 7 – Performance Optimization (Before vs After)")

# TEST QUERY (Used for all performance tests)
def run_query(df):
    # The previous error indicated 'TotalPrice' column was not found.
    # Based on the feature engineering step, 'Revenue' is the correct column.
    return df.groupBy("Country").sum("Revenue").collect()


# 1. PARTITIONING OPTIMIZATION

# Before Partitioning
start = time.time()
run_query(feature_df) # Corrected from gold_df to feature_df
before_partition = time.time() - start

# After Partitioning
partitioned_df = feature_df.repartition("Country") # Corrected from gold_df to feature_df
start = time.time()
run_query(partitioned_df)
after_partition = time.time() - start

partition_improvement = ((before_partition - after_partition) / before_partition) * 100


# 2. CACHING OPTIMIZATION

# Before Caching
start = time.time()
run_query(feature_df) # Corrected from gold_df to feature_df
before_cache = time.time() - start

# After Caching
cached_df = feature_df.cache() # Corrected from gold_df to feature_df
cached_df.count()  # Force cache
start = time.time()
run_query(cached_df)
after_cache = time.time() - start

cache_improvement = ((before_cache - after_cache) / before_cache) * 100


# 3. BROADCAST JOIN OPTIMIZATION

# Normal Join (Before Broadcast)
start = time.time()
normal_join = feature_df.join(dim_customers, "CustomerID", "left") # Corrected from gold_df to feature_df
normal_join.collect()
before_broadcast = time.time() - start

# Broadcast Join (After Optimization)
start = time.time()
broadcast_join = feature_df.join( # Corrected from gold_df to feature_df
    broadcast(dim_customers),
    "CustomerID"
)
broadcast_join.collect()
after_broadcast = time.time() - start

broadcast_improvement = ((before_broadcast - after_broadcast) / before_broadcast) * 100


# FINAL TABLE VALUES
print("\n========== REPORT ==========")
print("Partitioning |", round(before_partition,2), "s |", round(after_partition,2), "s |", round(partition_improvement,2), "%")
print("Caching      |", round(before_cache,2), "s |", round(after_cache,2), "s |", round(cache_improvement,2), "%")
print("Broadcast    |", round(before_broadcast,2), "s |", round(after_broadcast,2), "s |", round(broadcast_improvement,2), "%")
# Out:
# TASK 7 – Performance Optimization (Before vs After)
#
# ========== REPORT ==========
# Partitioning | 0.27 s | 0.74 s | -170.39 %
# Caching      | 0.62 s | 0.37 s | 40.68 %
# Broadcast    | 14.72 s | 15.49 s | -5.24 %

# %% [markdown]
# # BONUS – Customer Cohort Retention Analysis

# %% [markdown]
# ### Step 1 - Create Invoice Month

# %%
from pyspark.sql.functions import trunc

# Extract invoice month (first day of month)
cohort_df = feature_df.withColumn(
    "InvoiceMonth",
    trunc("InvoiceDate", "month")
)

# %% [markdown]
# ### Step 2 - Identify First Purchase Month (Cohort Month)

# %%
from pyspark.sql.functions import min

# Find first purchase month per customer
cohort_month_df = cohort_df.groupBy("CustomerID") \
    .agg(min("InvoiceMonth").alias("CohortMonth"))

# %% [markdown]
# ### Step 3 - Join Back To Main Data

# %%
cohort_data = cohort_df.join(
    cohort_month_df,
    "CustomerID"
)

# %% [markdown]
# ### STEP 4 - Calculate Months Since First Purchase

# %%
from pyspark.sql.functions import months_between

cohort_data = cohort_data.withColumn(
    "CohortIndex",
    months_between("InvoiceMonth", "CohortMonth").cast("int")
)

# %% [markdown]
# ### STEP 5 - Count Active Customers Per *Cohort*

# %%
retention_table = cohort_data.groupBy(
    "CohortMonth", "CohortIndex"
).agg(
    count("CustomerID").alias("ActiveCustomers")
)

retention_table.show()
# Out:
# +-----------+-----------+---------------+
# |CohortMonth|CohortIndex|ActiveCustomers|
# +-----------+-----------+---------------+
# | 2011-03-01|          7|           3271|
# | 2010-12-01|         11|          20168|
# | 2011-08-01|          1|           1439|
# | 2010-12-01|         10|          12331|
# | 2011-02-01|          9|           2607|
# | 2011-02-01|          8|           2690|
# | 2011-02-01|          5|           1826|
# | 2011-01-01|          9|           4572|
# | 2011-06-01|          1|            858|
# | 2011-05-01|          6|           1880|
# | 2011-03-01|          2|           2287|
# | 2011-05-01|          4|           1391|
# | 2011-06-01|          5|           2359|
# | 2011-04-01|          5|           1864|
# | 2011-02-01|          3|           2201|
# | 2011-04-01|          2|           1123|
# | 2011-05-01|          5|           2181|
# | 2010-12-01|          6|          10022|
# | 2011-01-01|          5|           2886|
# | 2011-10-01|          1|           3257|
# +-----------+-----------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### STEP 6 - Calculate Retention Rate

# %%
from pyspark.sql.functions import first

# Get initial cohort size
cohort_size = retention_table.filter(
    retention_table.CohortIndex == 0
).select("CohortMonth",
         col("ActiveCustomers").alias("CohortSize"))

# Join back
retention_rate = retention_table.join(
    cohort_size,
    "CohortMonth"
)

retention_rate = retention_rate.withColumn(
    "RetentionRate",
    col("ActiveCustomers") / col("CohortSize")
)

retention_rate.show()
# Out:
# +-----------+-----------+---------------+----------+-------------------+
# |CohortMonth|CohortIndex|ActiveCustomers|CohortSize|      RetentionRate|
# +-----------+-----------+---------------+----------+-------------------+
# | 2011-05-01|          7|            717|      5379|0.13329615170105968|
# | 2011-05-01|          3|            821|      5379|0.15263060048336122|
# | 2011-05-01|          1|            969|      5379|0.18014500836586725|
# | 2011-05-01|          2|            840|      5379| 0.1561628555493586|
# | 2011-05-01|          0|           5379|      5379|                1.0|
# | 2011-05-01|          5|           2181|      5379|0.40546569994422754|
# | 2011-05-01|          4|           1391|      5379|0.25859825246328316|
# | 2011-05-01|          6|           1880|      5379|0.34950734337237405|
# | 2011-10-01|          2|            814|     10690|0.07614593077642656|
# | 2011-10-01|          0|          10690|     10690|                1.0|
# | 2011-10-01|          1|           3257|     10690| 0.3046772684752105|
# | 2011-03-01|          1|           1275|     10159|0.12550447878728221|
# | 2011-03-01|          9|            908|     10159|0.08937887587360961|
# | 2011-03-01|          5|           1936|     10159|0.19056993798602226|
# | 2011-03-01|          6|           2733|     10159|0.26902254158873906|
# | 2011-03-01|          8|           3914|     10159| 0.3852741411556255|
# | 2011-03-01|          4|           2228|     10159|0.21931292450044296|
# | 2011-03-01|          0|          10159|     10159|                1.0|
# | 2011-03-01|          3|           2097|     10159|0.20641795452308298|
# | 2011-03-01|          2|           2287|     10159|0.22512058273452112|
# +-----------+-----------+---------------+----------+-------------------+
# only showing top 20 rows
